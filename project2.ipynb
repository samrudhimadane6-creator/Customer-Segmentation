# %% [markdown]
# <a href="https://colab.research.google.com/github/samrudhimadane6-creator/Customer-Segmentation/blob/main/project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym
import random

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
observation, info = env.reset()

print(observation)
# Out:
# [-0.02344654  0.01167642 -0.02546185  0.02722657]

# %%
for i in range(10):

    action = env.action_space.sample()

    observation, reward, terminated, truncated, info = env.step(action)

    print("Action:", action)
    print("Reward:", reward)
# Out:
# Action: 0
# Reward: 1.0
# Action: 0
# Reward: 1.0
# Action: 0
# Reward: 1.0
# Action: 1
# Reward: 1.0
# Action: 0
# Reward: 1.0
# Action: 0
# Reward: 1.0
# Action: 1
# Reward: 1.0
# Action: 1
# Reward: 1.0
# Action: 0
# Reward: 1.0
# Action: 0
# Reward: 1.0

# %%
import matplotlib.pyplot as plt

img = env.render()

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
observation, info = env.reset()

total_reward = 0

for step in range(100):

    action = env.action_space.sample()

    observation, reward, terminated, truncated, info = env.step(action)

    total_reward += reward

    if terminated or truncated:
        break

print("Total Reward:", total_reward)
# Out:
# Total Reward: 14.0

# %%
env.close()
