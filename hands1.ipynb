# %% [markdown]
# <a href="https://colab.research.google.com/github/samrudhimadane6-creator/Customer-Segmentation/blob/main/hands1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym
import random
import time

# Create Environment
env = gym.make("CartPole-v1", render_mode="human")

episodes = 5

for episode in range(episodes):

    state, info = env.reset()
    done = False
    score = 0

    while not done:

        # Random Action
        action = env.action_space.sample()

        # Perform Action
        next_state, reward, terminated, truncated, info = env.step(action)

        done = terminated or truncated

        score += reward

        print("Reward:", reward)

        time.sleep(0.02)

    print("Episode:", episode + 1, "Score:", score)

env.close()
# Out:
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Episode: 1 Score: 15.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Episode: 2 Score: 42.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# Reward: 1.0
# ...
