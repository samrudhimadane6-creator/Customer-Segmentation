# %% [markdown]
# <a href="https://colab.research.google.com/github/samrudhimadane6-creator/Customer-Segmentation/blob/main/hands6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium[toy-text]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 53.8 MB/s eta 0:00:00
# ...

# %%
import gymnasium as gym
import random

env = gym.make("Blackjack-v1")

returns = {}

for episode in range(5000):

    state, info = env.reset()

    done = False

    episode_memory = []

    while not done:

        action = random.choice([0,1])

        next_state, reward, terminated, truncated, info = env.step(action)

        done = terminated or truncated

        episode_memory.append((state, reward))

        state = next_state

    for state, reward in episode_memory:

        if state not in returns:
            returns[state] = []

        returns[state].append(reward)

print("Learned States:", len(returns))
# Out:
# Learned States: 276
